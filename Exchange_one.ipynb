# %%
import pandas as pd                                   
from bs4 import BeautifulSoup                          
import requests  
import datetime
from time import sleep

headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.86 Safari/537.36'
}

df1 = pd.read_excel('exchange_all_listings.xlsx')
all_links = df1['links'].tolist()
print(len(all_links))
data = []
list = {}

counter = 0
with requests.Session() as s:
    for i in range(1,417):
    #     sleep(2)
        counter += 1
        print(counter)
        url = f'https://exchangemarketplace.com/shops?page={i}&sortBy=createdAtHighToLow'
        try:
            r = s.get(url, headers = headers, timeout = 30)
            sleep(4)
            soup = BeautifulSoup(r.content, 'html5lib')
            listing_link = []

            for link in soup.findAll('a', attrs={'class': '_3gf3d xQBnN _1oHwA'}):
                links = link.get('href')
                links1 = f'https://exchangemarketplace.com{links}'
                listing_link.append(links1)
#                 print(links1)
                if links1 in all_links:
                    pass
                else:
                    print(links1)
                    list = {
                    'links': links1
                    }


                try:
                    data.append(list)
                except:
                    pass
            print('Total links found in one page:',len(listing_link))
            listing_link = []
            
        except:
            print('loading failed')
        

df = pd.DataFrame(data)
done = df.drop_duplicates(keep='first') # removing duplicate rows. index will remain same
dn = done.reset_index(drop=True) #droping previous index
dn.to_excel('exchange_all_listings_today.xlsx',index= False) # saving as excel

sleep(3)


import os
import glob
import pandas as pd
import datetime
x = datetime.datetime.now()
hour = x.hour
minute = x.minute
date_1= x.day
month = x.month
year = x.year
date_time1 = f'{date_1}-{month}-{year}_{hour}-{minute}'

all_filenames = []
for file in os.listdir():
    if 'exchange_all_listings.xlsx' in file:
        all_filenames.append(file)
    if 'exchange_all_listings_today.xlsx' in file:
        all_filenames.append(file)
#         print(f'file name: {file}')
print(all_filenames)       
        
        
        
combined_csv = pd.concat([pd.read_excel(f) for f in all_filenames ])
combined_csv.to_excel("exchange_all_listings.xlsx", index=False ,encoding='utf-8')
# Out:
# 11925
# 1
# https://exchangemarketplace.com/shops/fashion-hermes-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/jewelry-hermes-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/fancy-swimsuit-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/pa-ni-pad
# https://exchangemarketplace.com/shops/pineapple-cell-accessories
# https://exchangemarketplace.com/shops/the-nirvana-fashion-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/nirvana-cosmetics-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/new-cute-dogs-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/fine-leather-bags-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/jewelry-yves-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/swimwear-kingdom-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/fashion-queen-bikini-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/women-fashion-leggings-all-products-ship-from-usa
# https://exchangemarketplace.com/shops/fabulously-fashion-north-east
# https://exchangemarketplace.com/shops/kittenbrush
# https://exchangemarketplace.com/shops/tron-projector
# https://exchangemarketplace.com/shops/cecealoveretail-com
# https://exchangemarketplace.com/shops/royal-roi
# https://exchangemarketplace.com/shops/hero-brand-store
# https://exchangemarketplace.com/shops/hellohoop
# https://exchangemarketplace.com/shops/dagutta
# https://exchangemarketplace.com/shops/appealing-pets-use-password-000
# https://exchangemarketplace.com/shops/stylish-legging-shop
# https://exchangemarketplace.com/shops/books-and-coffee-treats
# Total links found in one page: 24
# 2
# https://exchangemarketplace.com/shops/sex-hookup-toys
# https://exchangemarketplace.com/shops/chara-store
# Total links found in one page: 24
# 3
# https://exchangemarketplace.com/shops/noble-pet-avenue
# Total links found in one page: 24
# 4
# https://exchangemarketplace.com/shops/hottie-golf
# https://exchangemarketplace.com/shops/kitchen-variety-shop
# Total links found in one page: 24
# 5
# https://exchangemarketplace.com/shops/d449f697c81e00d4fe46b43d18a10396
# Total links found in one page: 24
# 6
# https://exchangemarketplace.com/shops/3f5509e455b33b0d938b289607ef32ae
# Total links found in one page: 24
# 7
# https://exchangemarketplace.com/shops/crossadvancetech
# Total links found in one page: 24
# 8
# https://exchangemarketplace.com/shops/reconquer
# Total links found in one page: 24
# 9
# https://exchangemarketplace.com/shops/51orologi-1
# https://exchangemarketplace.com/shops/urban-minimalist
# Total links found in one page: 24
# 10
# Total links found in one page: 24
# 11
# Total links found in one page: 24
# 12
# https://exchangemarketplace.com/shops/gamelab
# Total links found in one page: 24
# 13
# https://exchangemarketplace.com/shops/kitchen-king
# Total links found in one page: 24
# 14
# https://exchangemarketplace.com/shops/scannrz
# Total links found in one page: 24
# 15
# Total links found in one page: 24
# 16
# https://exchangemarketplace.com/shops/a3cb14c56cef503cdae48eab17ef942e
# Total links found in one page: 24
# 17
# Total links found in one page: 24
# 18
# Total links found in one page: 24
# 19
# Total links found in one page: 24
# 20
# Total links found in one page: 24
# 21
# https://exchangemarketplace.com/shops/kaffeesuchtig
# Total links found in one page: 24
# 22
# Total links found in one page: 24
# 23
# https://exchangemarketplace.com/shops/common-hair
# https://exchangemarketplace.com/shops/tranquiliture
# https://exchangemarketplace.com/shops/splendor-dog-boutique
# https://exchangemarketplace.com/shops/wrap-lights
# https://exchangemarketplace.com/shops/james-bivins
# https://exchangemarketplace.com/shops/haircube-store
# https://exchangemarketplace.com/shops/oceancalls
# https://exchangemarketplace.com/shops/pet-supply-company
# https://exchangemarketplace.com/shops/worthysteals
# https://exchangemarketplace.com/shops/ntss
# https://exchangemarketplace.com/shops/peacefully4me
# https://exchangemarketplace.com/shops/mirzatci
# https://exchangemarketplace.com/shops/beginners-gardening-store
# Total links found in one page: 24
# 24
# https://exchangemarketplace.com/shops/goldplatedjewellerystore
# https://exchangemarketplace.com/shops/smarty-band
# https://exchangemarketplace.com/shops/koolvio
# https://exchangemarketplace.com/shops/fam-bam-apparel-for-your-fam-base
# Total links found in one page: 24
# 25
# https://exchangemarketplace.com/shops/snoop-gold
# Total links found in one page: 24
# 26
# Total links found in one page: 24
# 27
# Total links found in one page: 24
# 28
# Total links found in one page: 24
# 29
# Total links found in one page: 24
# 30
# Total links found in one page: 24
# 31
# Total links found in one page: 24
# 32
# Total links found in one page: 24
# 33
# https://exchangemarketplace.com/shops/trendsinone
# Total links found in one page: 24
# 34
# Total links found in one page: 24
# 35
# https://exchangemarketplace.com/shops/oxygen-tracker
# https://exchangemarketplace.com/shops/glowara
# https://exchangemarketplace.com/shops/uenergy
# Total links found in one page: 24
# 36
# Total links found in one page: 24
# 37
# Total links found in one page: 24
# 38
# Total links found in one page: 24
# 39
# Total links found in one page: 24
# 40
# Total links found in one page: 24
# 41
# Total links found in one page: 24
# 42
# Total links found in one page: 24
# 43
# Total links found in one page: 24
# 44
# Total links found in one page: 24
# 45
# Total links found in one page: 24
# 46
# Total links found in one page: 24
# 47
# Total links found in one page: 24
# 48
# Total links found in one page: 24
# 49
# Total links found in one page: 24
# 50
# Total links found in one page: 24
# 51
# https://exchangemarketplace.com/shops/4e5ffe31daf29723fea4723d4ca3c228
# Total links found in one page: 24
# 52
# Total links found in one page: 24
# 53
# Total links found in one page: 24
# 54
# Total links found in one page: 24
# 55
# https://exchangemarketplace.com/shops/smilegarcia-store
# Total links found in one page: 24
# 56
# Total links found in one page: 24
# 57
# Total links found in one page: 24
# 58
# Total links found in one page: 24
# 59
# Total links found in one page: 24
# 60
# Total links found in one page: 24
# 61
# Total links found in one page: 24
# 62
# Total links found in one page: 24
# 63
# Total links found in one page: 24
# 64
# Total links found in one page: 24
# 65
# Total links found in one page: 24
# 66
# https://exchangemarketplace.com/shops/we-wear-liberty
# Total links found in one page: 24
# 67
# Total links found in one page: 24
# 68
# Total links found in one page: 24
# 69
# https://exchangemarketplace.com/shops/nebula-projector
# Total links found in one page: 24
# 70
# Total links found in one page: 24
# 71
# Total links found in one page: 24
# 72
# Total links found in one page: 24
# 73
# Total links found in one page: 24
# 74
# Total links found in one page: 24
# 75
# https://exchangemarketplace.com/shops/golphers
# Total links found in one page: 24
# 76
# https://exchangemarketplace.com/shops/1e22c92a3198289aa02bcf88fb5dfe8e
# Total links found in one page: 24
# 77
# Total links found in one page: 24
# 78
# Total links found in one page: 24
# 79
# Total links found in one page: 24
# 80
# https://exchangemarketplace.com/shops/07-smart-watch
# https://exchangemarketplace.com/shops/08-smart-watch
# https://exchangemarketplace.com/shops/10-smart-watch
# https://exchangemarketplace.com/shops/09-smart-watch
# https://exchangemarketplace.com/shops/tealull
# https://exchangemarketplace.com/shops/booboos
# https://exchangemarketplace.com/shops/a-butterflys-dresser
# https://exchangemarketplace.com/shops/women-shoulders-bags
# https://exchangemarketplace.com/shops/canvas-picturet
# https://exchangemarketplace.com/shops/women-pijama-setv
# Total links found in one page: 24
# 81
# https://exchangemarketplace.com/shops/good-mens-watches
# https://exchangemarketplace.com/shops/christmass-pendant-shop
# https://exchangemarketplace.com/shops/women-3d-hoodies-shop
# https://exchangemarketplace.com/shops/3d-metal-puzzlea
# https://exchangemarketplace.com/shops/best-good-watches
# https://exchangemarketplace.com/shops/raven-prism
# https://exchangemarketplace.com/shops/happydoggiez-1
# Total links found in one page: 24
# 82
# Total links found in one page: 24
# 83
# Total links found in one page: 24
# 84
# Total links found in one page: 24
# 85
# https://exchangemarketplace.com/shops/shapewearsize
# Total links found in one page: 24
# 86
# Total links found in one page: 24
# 87
# Total links found in one page: 24
# 88
# Total links found in one page: 24
# 89
# Total links found in one page: 24
# 90
# Total links found in one page: 24
# 91
# Total links found in one page: 24
# 92
# Total links found in one page: 24
# 93
# Total links found in one page: 24
# 94
# Total links found in one page: 24
# 95
# Total links found in one page: 24
# 96
# Total links found in one page: 24
# 97
# Total links found in one page: 24
# 98
# Total links found in one page: 24
# 99
# Total links found in one page: 24
# 100
# Total links found in one page: 24
# 101
# Total links found in one page: 24
# 102
# Total links found in one page: 24
# 103
# Total links found in one page: 24
# 104
# Total links found in one page: 24
# 105
# Total links found in one page: 24
# 106
# Total links found in one page: 24
# 107
# Total links found in one page: 24
# 108
# Total links found in one page: 24
# 109
# Total links found in one page: 24
# 110
# Total links found in one page: 24
# 111
# Total links found in one page: 24
# 112
# Total links found in one page: 24
# 113
# Total links found in one page: 24
# 114
# Total links found in one page: 24
# 115
# Total links found in one page: 24
# 116
# Total links found in one page: 24
# 117
# Total links found in one page: 24
# 118
# Total links found in one page: 24
# 119
# Total links found in one page: 24
# 120
# Total links found in one page: 24
# 121
# Total links found in one page: 24
# 122
# Total links found in one page: 24
# 123
# Total links found in one page: 24
# 124
# Total links found in one page: 24
# 125
# Total links found in one page: 24
# 126
# Total links found in one page: 24
# 127
# Total links found in one page: 24
# 128
# Total links found in one page: 24
# 129
# Total links found in one page: 24
# 130
# Total links found in one page: 24
# 131
# Total links found in one page: 24
# 132
# Total links found in one page: 24
# 133
# Total links found in one page: 24
# 134
# Total links found in one page: 24
# 135
# Total links found in one page: 24
# 136
# Total links found in one page: 24
# 137
# Total links found in one page: 24
# 138
# Total links found in one page: 24
# 139
# Total links found in one page: 24
# 140
# Total links found in one page: 24
# 141
# https://exchangemarketplace.com/shops/louis-loire
# Total links found in one page: 24
# 142
# Total links found in one page: 24
# 143
# Total links found in one page: 24
# 144
# Total links found in one page: 24
# 145
# Total links found in one page: 24
# 146
# Total links found in one page: 24
# 147
# Total links found in one page: 24
# 148
# Total links found in one page: 24
# 149
# Total links found in one page: 24
# 150
# Total links found in one page: 24
# 151
# Total links found in one page: 24
# 152
# Total links found in one page: 24
# 153
# Total links found in one page: 24
# 154
# Total links found in one page: 24
# 155
# Total links found in one page: 24
# 156
# Total links found in one page: 24
# 157
# Total links found in one page: 0
# 158
# Total links found in one page: 24
# 159
# Total links found in one page: 24
# 160
# Total links found in one page: 24
# 161
# Total links found in one page: 24
# 162
# Total links found in one page: 24
# 163
# Total links found in one page: 24
# 164
# Total links found in one page: 24
# 165
# Total links found in one page: 24
# 166
# Total links found in one page: 24
# 167
# Total links found in one page: 24
# 168
# Total links found in one page: 0
# 169
# Total links found in one page: 24
# 170
# https://exchangemarketplace.com/shops/e562f35ea619a5d5ce10c50484bb55bf
# Total links found in one page: 24
# 171
# Total links found in one page: 24
# 172
# Total links found in one page: 24
# 173
# Total links found in one page: 24
# 174
# Total links found in one page: 24
# 175
# Total links found in one page: 24
# 176
# Total links found in one page: 24
# 177
# Total links found in one page: 24
# 178
# Total links found in one page: 24
# 179
# Total links found in one page: 24
# 180
# Total links found in one page: 24
# 181
# Total links found in one page: 24
# 182
# Total links found in one page: 24
# 183
# Total links found in one page: 24
# 184
# Total links found in one page: 24
# 185
# Total links found in one page: 24
# 186
# Total links found in one page: 24
# 187
# Total links found in one page: 24
# 188
# Total links found in one page: 24
# 189
# Total links found in one page: 0
# 190
# Total links found in one page: 24
# 191
# Total links found in one page: 24
# 192
# Total links found in one page: 24
# 193
# Total links found in one page: 24
# 194
# Total links found in one page: 24
# 195
# Total links found in one page: 24
# 196
# Total links found in one page: 24
# 197
# Total links found in one page: 24
# 198
# Total links found in one page: 24
# 199
# Total links found in one page: 24
# 200
# Total links found in one page: 24
# 201
# Total links found in one page: 24
# 202
# https://exchangemarketplace.com/shops/fishyholics
# https://exchangemarketplace.com/shops/petlovepat
# Total links found in one page: 24
# 203
# https://exchangemarketplace.com/shops/05311bab6cd538a12cc727229f82d1a5
# Total links found in one page: 24
# 204
# Total links found in one page: 24
# 205
# Total links found in one page: 24
# 206
# Total links found in one page: 24
# 207
# Total links found in one page: 24
# 208
# Total links found in one page: 24
# 209
# Total links found in one page: 24
# 210
# Total links found in one page: 0
# 211
# Total links found in one page: 24
# 212
# Total links found in one page: 24
# 213
# Total links found in one page: 24
# 214
# Total links found in one page: 24
# 215
# Total links found in one page: 24
# 216
# Total links found in one page: 24
# 217
# Total links found in one page: 24
# 218
# Total links found in one page: 24
# 219
# Total links found in one page: 24
# 220
# Total links found in one page: 24
# 221
# Total links found in one page: 24
# 222
# Total links found in one page: 24
# 223
# Total links found in one page: 24
# 224
# Total links found in one page: 24
# 225
# Total links found in one page: 24
# 226
# Total links found in one page: 24
# 227
# https://exchangemarketplace.com/shops/05de977800f66bc817fb136f4ba1bf44
# Total links found in one page: 24
# 228
# Total links found in one page: 24
# 229
# Total links found in one page: 24
# 230
# Total links found in one page: 24
# 231
# Total links found in one page: 24
# 232
# Total links found in one page: 24
# 233
# Total links found in one page: 24
# 234
# Total links found in one page: 24
# 235
# Total links found in one page: 24
# 236
# Total links found in one page: 24
# 237
# Total links found in one page: 24
# 238
# Total links found in one page: 24
# 239
# Total links found in one page: 24
# 240
# Total links found in one page: 24
# 241
# Total links found in one page: 24
# 242
# Total links found in one page: 24
# 243
# Total links found in one page: 24
# 244
# Total links found in one page: 24
# 245
# Total links found in one page: 24
# 246
# Total links found in one page: 24
# 247
# Total links found in one page: 24
# 248
# Total links found in one page: 24
# 249
# Total links found in one page: 24
# 250
# Total links found in one page: 24
# 251
# Total links found in one page: 24
# 252
# Total links found in one page: 24
# 253
# Total links found in one page: 24
# 254
# Total links found in one page: 24
# 255
# Total links found in one page: 24
# 256
# Total links found in one page: 24
# 257
# Total links found in one page: 24
# 258
# Total links found in one page: 24
# 259
# Total links found in one page: 24
# 260
# Total links found in one page: 24
# 261
# Total links found in one page: 0
# 262
# Total links found in one page: 24
# 263
# Total links found in one page: 24
# 264
# Total links found in one page: 24
# 265
# Total links found in one page: 24
# 266
# https://exchangemarketplace.com/shops/9ea63e6c471730171f97e9875fe0f27d
# Total links found in one page: 24
# 267
# Total links found in one page: 24
# 268
# https://exchangemarketplace.com/shops/crxnu
# https://exchangemarketplace.com/shops/ignitine
# Total links found in one page: 24
# 269
# Total links found in one page: 24
# 270
# Total links found in one page: 24
# 271
# Total links found in one page: 24
# 272
# Total links found in one page: 0
# 273
# Total links found in one page: 24
# 274
# Total links found in one page: 24
# 275
# Total links found in one page: 24
# 276
# Total links found in one page: 24
# 277
# https://exchangemarketplace.com/shops/dankpins
# Total links found in one page: 24
# 278
# Total links found in one page: 24
# 279
# Total links found in one page: 24
# 280
# Total links found in one page: 24
# 281
# Total links found in one page: 24
# 282
# Total links found in one page: 24
# 283
# Total links found in one page: 0
# 284
# Total links found in one page: 24
# 285
# Total links found in one page: 24
# 286
# Total links found in one page: 24
# 287
# Total links found in one page: 24
# 288
# Total links found in one page: 24
# 289
# Total links found in one page: 24
# 290
# Total links found in one page: 24
# 291
# Total links found in one page: 24
# 292
# Total links found in one page: 24
# 293
# Total links found in one page: 24
# 294
# Total links found in one page: 0
# 295
# Total links found in one page: 24
# 296
# Total links found in one page: 24
# 297
# Total links found in one page: 24
# 298
# Total links found in one page: 24
# 299
# Total links found in one page: 24
# 300
# Total links found in one page: 24
# 301
# Total links found in one page: 24
# 302
# Total links found in one page: 24
# 303
# Total links found in one page: 24
# 304
# Total links found in one page: 24
# 305
# Total links found in one page: 0
# 306
# Total links found in one page: 24
# 307
# Total links found in one page: 24
# 308
# Total links found in one page: 24
# 309
# Total links found in one page: 24
# 310
# Total links found in one page: 24
# 311
# Total links found in one page: 24
# 312
# Total links found in one page: 24
# 313
# Total links found in one page: 24
# 314
# Total links found in one page: 24
# 315
# Total links found in one page: 24
# 316
# Total links found in one page: 0
# 317
# Total links found in one page: 24
# 318
# Total links found in one page: 24
# 319
# Total links found in one page: 24
# 320
# Total links found in one page: 24
# 321
# Total links found in one page: 24
# 322
# Total links found in one page: 24
# 323
# Total links found in one page: 24
# 324
# Total links found in one page: 24
# 325
# Total links found in one page: 24
# 326
# Total links found in one page: 24
# 327
# Total links found in one page: 0
# 328
# Total links found in one page: 24
# 329
# Total links found in one page: 24
# 330
# Total links found in one page: 24
# 331
# Total links found in one page: 24
# 332
# Total links found in one page: 24
# 333
# Total links found in one page: 24
# 334
# Total links found in one page: 24
# 335
# Total links found in one page: 24
# 336
# Total links found in one page: 24
# 337
# Total links found in one page: 24
# 338
# Total links found in one page: 0
# 339
# Total links found in one page: 24
# 340
# Total links found in one page: 24
# 341
# https://exchangemarketplace.com/shops/96f5feae278e05e464b15520db115a96
# Total links found in one page: 24
# 342
# Total links found in one page: 24
# 343
# Total links found in one page: 24
# 344
# Total links found in one page: 24
# 345
# https://exchangemarketplace.com/shops/accessoriesshoping
# Total links found in one page: 24
# 346
# Total links found in one page: 24
# 347
# Total links found in one page: 24
# 348
# Total links found in one page: 24
# 349
# Total links found in one page: 24
# 350
# Total links found in one page: 24
# 351
# Total links found in one page: 24
# 352
# Total links found in one page: 24
# 353
# Total links found in one page: 24
# 354
# Total links found in one page: 24
# 355
# Total links found in one page: 24
# 356
# Total links found in one page: 24
# 357
# Total links found in one page: 24
# 358
# Total links found in one page: 24
# 359
# Total links found in one page: 0
# 360
# Total links found in one page: 24
# 361
# Total links found in one page: 24
# 362
# Total links found in one page: 24
# 363
# Total links found in one page: 24
# 364
# Total links found in one page: 24
# 365
# Total links found in one page: 24
# 366
# Total links found in one page: 24
# 367
# Total links found in one page: 24
# 368
# Total links found in one page: 24
# 369
# Total links found in one page: 24
# 370
# Total links found in one page: 0
# 371
# Total links found in one page: 24
# 372
# Total links found in one page: 24
# 373
# Total links found in one page: 24
# 374
# Total links found in one page: 24
# 375
# https://exchangemarketplace.com/shops/swtbaby
# Total links found in one page: 24
# 376
# Total links found in one page: 24
# 377
# Total links found in one page: 24
# 378
# Total links found in one page: 24
# 379
# Total links found in one page: 24
# 380
# Total links found in one page: 24
# 381
# Total links found in one page: 0
# 382
# Total links found in one page: 24
# 383
# Total links found in one page: 24
# 384
# Total links found in one page: 24
# 385
# Total links found in one page: 24
# 386
# https://exchangemarketplace.com/shops/good-posture-store
# Total links found in one page: 24
# 387
# Total links found in one page: 24
# 388
# Total links found in one page: 24
# 389
# Total links found in one page: 24
# 390
# Total links found in one page: 24
# 391
# Total links found in one page: 24
# 392
# Total links found in one page: 0
# 393
# Total links found in one page: 24
# 394
# Total links found in one page: 24
# 395
# Total links found in one page: 24
# 396
# Total links found in one page: 24
# 397
# Total links found in one page: 24
# 398
# Total links found in one page: 24
# 399
# Total links found in one page: 24
# 400
# Total links found in one page: 24
# 401
# Total links found in one page: 24
# 402
# Total links found in one page: 24
# 403
# Total links found in one page: 0
# 404
# Total links found in one page: 24
# 405
# Total links found in one page: 24
# 406
# Total links found in one page: 24
# 407
# Total links found in one page: 24
# 408
# Total links found in one page: 24
# 409
# Total links found in one page: 24
# 410
# Total links found in one page: 24
# 411
# Total links found in one page: 24
# 412
# Total links found in one page: 24
# 413
# Total links found in one page: 24
# 414
# Total links found in one page: 0
# 415
# Total links found in one page: 24
# 416
# Total links found in one page: 24
# ['exchange_all_listings.xlsx', 'exchange_all_listings_today.xlsx']
